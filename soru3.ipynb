# %%
isim =str(input("isim giriniz:"))


isim_harfleri = [letter for letter in isim]


isim_harfleri = []
for letter in isim:
    isim_harfleri.append(letter)


print(isim_harfleri)
# Out:
# isim giriniz:onat
# ['o', 'n', 'a', 't']
