# %%
sayilar=input("Sayıları virgülle ayırarak girin:").split(",")
toplam=0
for sayi in sayilar:
    toplam+=int(sayi)
print("Sayıların toplamı:",toplam)
# Out:
# Sayıları virgülle ayırarak girin:4,12,16,21
# Sayıların toplamı: 53
