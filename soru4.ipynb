# %%
my_tuple=(0,1,2,"hi",4,5)
print("orijinal tuple:",my_tuple)
n_list=list(my_tuple)
n_list[3]=3
my_tuple=tuple(n_list)
print("Yeni tuple:",my_tuple)
# Out:
# orijinal tuple: (0, 1, 2, 'hi', 4, 5)
# Yeni tuple: (0, 1, 2, 3, 4, 5)
